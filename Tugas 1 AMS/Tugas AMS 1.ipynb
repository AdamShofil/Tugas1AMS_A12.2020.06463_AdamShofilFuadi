# %% [markdown]
# ## Eksperimen dan Pengumpulan Dataset

# %% [markdown]
# ## Pemanggilan Library 1

# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    
    # Autentikasi dan akses menggunakan keys
    auth = tweepy.OAuthHandler("Ow2TUoODybHnty5jOWz82xY7J", 
    "p7Ff6AqkccFvQCIKi542yRETvUh3CMYfwq15JVbWpab5ZqF6V3")
    auth.set_access_token("1572073503544967168-cGj4aRIj8iq983O1WCkF1cuE9r81xV", 
    "eHKgEFA6IrWHoONQ27Ub7Kmz6IpHJKYkDicUL4NPuaFTh")
    
    # Kembalikan akses ke API
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# Membuat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %% [markdown]
# ## Ambil Tweet dari Username
# Username yang saya gunakan yakni @MataNajwa

# %%
tweets = extractor.user_timeline(screen_name="ernestprakasa", count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))

print("100 tweet teratas:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 198.
#
# 100 tweet teratas:
#
# RT @vanlith_gl: Pesanku untuk pengusaha sablon, jelang 2024 pokoknya jangan mau mengerjakan order kaos kampanye dan sebagainya tanpa kejela…
#
# RT @pinot: someeetimesas you'rre lucky if almigjhty d0esn't disconnect your nnnerves. be ggraateful. https://t.co/LnKgokNmBl
#
# Angkatan CCS / wiro paham nih... https://t.co/AKwyAuysUo
#
# Toksik bener bocah busetttttt https://t.co/b5njNjTgqb
#
# Akun2 provokator yang lagi manasin mesin 2024 ini ga perlu ditanggepin lah. Malah dapet awareness.
#
# @acotenri @EnzyStoria MAU
#
# 🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡 https://t.co/U2PfokbeOA
#
# Sedih beneran disangka nyindir. Elu aje yg sensi. 😂 https://t.co/jo2OFTYcU3
#
# Walau gw fans Spurs, gw harus akui, trisula lini depan Arsenal Saka-Jesus-Martinelli ini kerennya minta ampun. 🫡
#
# Desember ini kita ketawa-ketawa di Bali yuk! ❤️ https://t.co/7qiaw09nfR
#
# RT @aimi_asi: Mantap Kak @nggirma ❤️
#
# RT @evimsofian: Idola banget. Farel keren. "Agamamu apa? Privasi."
#
# Tolong ini dinormalisasi. https://t.co/WEIWVeKO2n
#
# RT @rezasnegara: Coba kamu liat wajah ibumu ketika lagi tidur, dialah yang dulu ngelahirin dan ngurusin kamu dari kecil, datangi belio geng…
#
# Yaudah gapapa kalo ternyata cepmek itu artinya cepak mekar, tapi bacanya yang bener dong cepmek jangan cepmek gitu… https://t.co/p7rxXMFxaX
#
# Ngalahin Haaland mah gampang, rendem aja di aer nanti juga korslet chip-nya.
#
# Andai Manchester City nggak beli cyborg buat jadi mesin gol, bisa-bisa Arsenal juara liga ini mah.
#
# RT @ditut: siapapun yg lg putus harapan,biarlah foto ini jd pengingat utk never give up hope &amp; suka cita.Bahkan dlm kondisi yg menurut org…
#
# RT @matt_gray_: YouTube is free education.
#
# But 98% don't know the best professors on its virtual campus.
#
# Here are the top 10 channels to…
#
# Waduh 😂 https://t.co/0AyiqgTZYn
#
# Udah sembuh ini mahhh 😂😂😂😂😂😂😂😂😂 https://t.co/hyDSlyKVfb
#
# @bicaraboxoffice Kuda hitam yg mengejutkan
#
# Lebih ke epilepsi ga sih? https://t.co/K7X57gWQoz
#
# Setting bahasa di henponnya langsung auto british. 👍 https://t.co/Ro8RCesk02
#
# @DianOnno The ultimate cringe
#
# @ryorhamono Waaahhhhhh 💪💪💪💪💪💪
#
# @bicaraboxoffice Gokssss
#
# Mauliate godang ❤️ https://t.co/w7nr2YzCHv
#
# RT @NetflixID: Apa yang biasanya suka emak kalian bungkusin begini ges? https://t.co/cciIHOuQDc
#
# RT @jakpost: Using the Kita Bisa online crowdfunding platform, Indonesia's BTS 'ARMY' raised more than Rp 447 million (US$29,316) in just o…
#
# RT @eshasw: Bali in the future https://t.co/WyMnTuyvto
#
# RT @moulysurya: Akhirnya bisa nonton “Ngeri-Ngeri Sedap” di @NetflixID Kayaknya ini film Indonesia pertama yang bikin gue nangis setelah Ad…
#
# Terlalu banyak kabar buruk. 😢
#
# Klo hotel, gw sih mending rekomen https://t.co/CyD89ayubj aja lah udah. Agoda kusut. https://t.co/Any5TSIhGk
#
# @miund @bene_dion @NetflixID Haha sanssss emg i didnt deserve credit. Cheers und, keep them lovely drawings coming! ❤️
#
# @miund @bene_dion @NetflixID Glad u enjoyed it 🙏❤️
#
# RT @NetflixID: Dua film Indonesia yang udah bisa ditonton di Netflix hari ini:
#
# ✅ Ngeri-Ngeri Sedap: tentang anak-anak yang akhirnya mudik,…
#
# RT @miund: Mohon tanggungjawabnya Abang @bene_dion sudah bikin mata saya bengkak gara2 nonton Ngeri-Ngeri Sedap di @NetflixID. Selamat atas…
#
# Yang belum sempat nonton di bioskop, silakan. Film perdana Imajinari karya @bene_dion yang akan mewakili Indonesia… https://t.co/PBQfiWliFk
#
# ❤️❤️❤️❤️❤️❤️❤️❤️ https://t.co/VUX9aXWWwt
#
# RT @adjisdoaibu: 🙏🏼🙏🏼🙏🏼 https://t.co/OIrhWlSicV
#
# Polower awal yang amat bangga sama pencapaian BiBo! 🫡 https://t.co/uRynQt3h5y
#
# RT @FCBayernEN: Prior to kick-off, we observed a minute of silence in memory of the victims of the Kanjuruhan Stadium tragedy in Indonesia…
#
# Meski pandeminya udah jadi endemi, tapi kebiasaan pejabat buat cuci tangan masih konsisten ya?
#
# @pinotski https://t.co/q48cW73NDU
#
# RT @AlissaWahid: Uluran kasih sayang teman2 semua sudah mulai kami hantarkan kepada keluarga korban #TragediKanjuruhan.
# Tidak akan bisa me…
#
# Asli gw gatau samsek kalo PSI ikut2an deklarasi. Ngapain sih, kayak suaranya ngaruh aja. 😔
#
# Buat yang bilang “Kenapa Nasdem diprotes PSI nggak”, gini guys jawabannya: GUA AJA BARU TAU DARI KALIAN KALO PSI DEKLARASI JUGA. 😔
#
# Harapan gw cuma 1, semoga nggak ada lagi pemecah-belahan bangsa kayak di 2 pemilu terakhir. Stop narasi cebong/kamp… https://t.co/cKdNnTCBmY
#
# Dengan resmi diumumkannya capres 2024, maka musim buzzer politik pun dimulai. It’s 2014 &amp; 2019 all over again. Brac… https://t.co/r0uAZiSmmO
#
# RT @kumparan: Sejumlah pemain dan official Arema FC mendatangi Stadion Kanjuruhan di Malang, Senin (3/10). Kedatangan tersebut sebagai bent…
#
# Semangat teman-teman, kami tetap menanti! ❤️ https://t.co/sXCED1O456
#
# 😭😭😭😭😭😭😭😭😭 https://t.co/Cw58pksyhd
#
# Cyborg. https://t.co/mXHJ4xqonx
#
# @ivannmakhsara @diazdanar Gudlak 👏👏👏👏👏👏
#
# Gw ga masalah sih Nasdem mau dukung capres mana, bodo amat. Tapi apa iya deklarasinya gak bisa ditunda dikit? Kita… https://t.co/Q88R1CGTHw
#
# RT @AlissaWahid: Tidak ada sepak bola senilai nyawa manusia...
# Hati tersayat oleh tragedi Kanjuruhan.
# Mari kita ulurkan tangan. GUSDURIAN p…
#
# RT @BudiSetyarso: Prasasti nama-nama korban. #KoranTempo https://t.co/nxzj23tpnQ
#
# RT @AhmadKawom: Setelah peretasan ada satu pesan ancaman kpd kru narasi :" DIAM ATAU MATI "
#
# Bantu narasi sebarkan kebenaran dengan RTL cui…
#
# “CASTING YUK!”, gitu? https://t.co/cjbio86kN5
#
# RT @panditfootball: Aksi solidaritas dari Bobotoh di Taman Cikapayang, Bandung. https://t.co/2z1TrpUcb0
#
# RT @AremaFC: Mohon izin meneruskan informasi dari kawan-kawan tenaga kesehatan RSUD Kanjuruhan.
#
# Apabila mengenali Aremania dan Aremanita…
#
# Sedih banget malah liat temen-temen twitwar segala. Udahlah, fokus aja sama orang-orang yang memang bertanggungjawa… https://t.co/MXdTWfAXnG
#
# RT @Spurs_ID: Tottenham Hotspur ingin menyampaikan belasungkawa kepada semua korban dan keluarga atas tragedi yang terjadi di Stadion Kanju…
#
# RT @aqfiazfan: Kami sudah memulai investigasi tragedi di Kanjuruhan dan butuh banyak informasi foto/video pasca match, saat match atau sesa…
#
# RT @FaktaSepakbola: 🚨BREAKING: Update per jam ini dari Dinkes Kabupaten Malang jumlah korban meninggal dunia 182 orang.
#
# Korban mayoritas b…
#
# RT @corbuzier: Mantap!! Polisi loe Prank KDRT!! Suka gue... Besok TNI sekalian.. gue temenin !! Asuuuh. #baimwong https://t.co/Rf0tstgBWv
#
# Good call. https://t.co/7dNcTs68zk
#
# Dear God 😭😭😭😭😭😭😭😭 https://t.co/54MvfiTHTq
#
# Terlalu mengerikan. Terlalu menyesakkan. Ya Tuhan. 😭
#
# RT @coldrebellion: Dua musibah stadion sepakbola yang paling banyak korban jiwa, Tragedi Lima (1964) dan Tragedi Accra (2001), sama-sama di…
#
# RT @adepedia: Bencana sepak bola terbesar di dunia itu terjadi di Lima, Peru tahun 1964 menewaskan 328 jiwa. Tebak pencetusnya apa? Gas air…
#
# Mohon maaf nih Pak Kapolda, tapi gas air mata di dalam stadion itu dilarang oleh FIFA. Mungkin alasannya ya supaya… https://t.co/5XFnm4kP7e
#
# Pak @jokowi, menteri anda ini lho. https://t.co/kga3jXvRIm
#
# Speechless 😭😭😭😭😭 https://t.co/9gZfXPrits
#
# Turut berduka atas tragedi di Kanjuruhan. 😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢
#
# @bicaraboxoffice Like &amp; Share bro
#
# Musim lalu Arteta &amp; “Trust the process” jadi bahan olok-olok massal. Sekarang hasilnya keren banget, rispek.
#
# Kartu merah dong. Yaudah, tutup aja aplikasi Vidionya 😂😂😂😂😂😂😂😂😂😂😂😂😂
#
# @annanneass U too? Bloody hell
#
# Arsenal sangar banget maennya. Bisa ini mah finish di top 2 kalo gak direcok cedera. Arteta udah lebih lama berproses, Conte butuh waktu.
#
# LLORIS MABOK CIUUUUUU 😔 2-1 Arsenal unggul lagiiiiii😂😂😂😂😂😂😂😂😂😂😂
#
# @SBKCF Anjir mana gw nonton lagi
#
# @SpursWebSeb Emerson not too shabby.
#
# Abis 1-1 Arsenal kayak rada goyang nih. Menarique. 😂
#
# 1-1. Seru gila anjayyyyyy COYS https://t.co/uhUu9QHbxZ
#
# Busettttttt Spurs kebobolan rudal.. gila banget Partey 🫡🫡🫡🫡🫡
#
# HEY https://t.co/ZRN26Mm1dl
#
# Kenapa bawa2 Rustu Recber sih 😂 https://t.co/d288ByDvPW
#
# Ketika menikah, saya &amp; istri tidak membuat perjanjian pembagian harta. Apa yang mau dibagi hartanya aja kaga ada. 😂
#
# RT @miund: Good thread. Banyak cari info, calon ibu, cari dokter dan RS yang pro ASI juga ya. Menyusuilah dengan keras kepala ✨
#
# @Chrisgcomedy Nasi isnt deep fried, get ur facts right! #twitterbullyingtrainingcourse
#
# BOS https://t.co/dlbi16esuO
#
# Siapa kira-kira pejabat / capres pertama yang bakal bikin video pake backsound “Kadang bikin akuuuu kesa!” hayo?
#
# RT @AdjieSanPutro: Hurry society. Pernah baca istilah yang menggambarkan masyarakat serba tergesa.
#
# Tergesa sukses. Tergesa naik jabatan. T…
#
# RT @bintangbete: selebritis: pamer kemesraan, eh gataunya di belakang ribut-ribut &amp; akhirnya bercerai.
#
# politisi: ribut-ribut, eh gataunya…
#
# WOY. https://t.co/huoQKf86XW
#
# @Adriandhy Tante 😢😢😢😢😢😢😢
#
# @pinot @garyvee @veefriends https://t.co/jGXKJnBxLY
#
# Baru beberapa halaman tapi langsung jatuh cinta sama tulisannya @okkymadasari. Akan jadi perjalanan membaca yang me… https://t.co/P1nSlPucEs
#
# RT @BiLLYKHAERUDIN: Sebulan lalu Menko PMK bilang 3 thn terakhir ada penurunan persentase bayi yang dapat ASI eksklusif. Pernyataan Menko P…

# %% [markdown]
# ## Masukan ke dalam dataframes Pandas

# %%
# Membuat kerangka data menggunakan sintaks berikut
dataset = pd.DataFrame(data = [tweet.text for tweet in tweets], columns = ['Tweets'])

# Tampilan kerangka data
display(dataset.head(100))
# Out:
#                                                Tweets
# 0   RT @vanlith_gl: Pesanku untuk pengusaha sablon...
# 1   RT @pinot: someeetimesas you'rre lucky if almi...
# 2   Angkatan CCS / wiro paham nih... https://t.co/...
# 3   Toksik bener bocah busetttttt https://t.co/b5n...
# 4   Akun2 provokator yang lagi manasin mesin 2024 ...
# ..                                                ...
# 95                       WOY. https://t.co/huoQKf86XW
# 96                           @Adriandhy Tante 😢😢😢😢😢😢😢
# 97  @pinot @garyvee @veefriends https://t.co/jGXKJ...
# 98  Baru beberapa halaman tapi langsung jatuh cint...
# 99  RT @BiLLYKHAERUDIN: Sebulan lalu Menko PMK bil...
#
# [100 rows x 1 columns]

# %%
dataset.to_csv('dataset_ernest.csv')

# %% [markdown]
# ## Cleaning Word

# %% [markdown]
# ## Import Library untuk Cleaning Word

# %%
import pandas as pd
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('dataset_ernest.csv')

df.head()
# Out:
#    Unnamed: 0                                             Tweets
# 0           0  RT @vanlith_gl: Pesanku untuk pengusaha sablon...
# 1           1  RT @pinot: someeetimesas you'rre lucky if almi...
# 2           2  Angkatan CCS / wiro paham nih... https://t.co/...
# 3           3  Toksik bener bocah busetttttt https://t.co/b5n...
# 4           4  Akun2 provokator yang lagi manasin mesin 2024 ...

# %%
df
# Out:
#      Unnamed: 0                                             Tweets
# 0             0  RT @vanlith_gl: Pesanku untuk pengusaha sablon...
# 1             1  RT @pinot: someeetimesas you'rre lucky if almi...
# 2             2  Angkatan CCS / wiro paham nih... https://t.co/...
# 3             3  Toksik bener bocah busetttttt https://t.co/b5n...
# 4             4  Akun2 provokator yang lagi manasin mesin 2024 ...
# ..          ...                                                ...
# 193         193  Ajegile udah 0-3 aja Arsenal. Udah ah nontonny...
# 194         194                           Maap salah, Partey ada 🙏
# 195         195  Eh iya maap. Partey ada ya. Tetep aja tanpa Od...
# 196         196  Penampilan brilian sang headliner @bene_dion d...
# 197         197  Arsenal mainnya bagus banget ya. Gokil Arteta ...
#
# [198 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  198 non-null    int64
#  1   Tweets      198 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# ## Preprocessing Dataset
#
# Pertama lakukan instalasi modul ekphrasis

# %%
# !pip install ekphrasis
# Out:
# Collecting ekphrasis
#   Downloading ekphrasis-0.5.4-py3-none-any.whl (83 kB)
# Requirement already satisfied: numpy in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (1.21.5)
# Collecting termcolor
#   Downloading termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: tqdm in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (4.64.0)
# Requirement already satisfied: matplotlib in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (3.5.1)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
# Requirement already satisfied: colorama in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (0.4.4)
# Requirement already satisfied: nltk in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (3.7)
# Requirement already satisfied: ujson in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (5.1.0)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\adam\anaconda3\lib\site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\adam\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Requirement already satisfied: click in c:\users\adam\anaconda3\lib\site-packages (from nltk->ekphrasis) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\adam\anaconda3\lib\site-packages (from nltk->ekphrasis) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\adam\anaconda3\lib\site-packages (from nltk->ekphrasis) (1.1.0)
# Installing collected packages: termcolor, ftfy, ekphrasis
# Successfully installed ekphrasis-0.5.4 ftfy-6.1.1 termcolor-2.0.1

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\Adam\anaconda3\lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Word statistics files not found!
# Downloading... done!
# Unpacking... done!
# Reading twitter - 1grams ...
# generating cache file for faster loading...
# reading ngrams C:\Users\Adam\.ekphrasis\stats\twitter\counts_1grams.txt
# Reading twitter - 2grams ...
# generating cache file for faster loading...
# reading ngrams C:\Users\Adam\.ekphrasis\stats\twitter\counts_2grams.txt
# Reading twitter - 1grams ...
# C:\Users\Adam\anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space(text):
    return " ".join(text.split())

def remove_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# ## Mulai proses pembersihan

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  RT @vanlith_gl: Pesanku untuk pengusaha sablon...
# 1           1  RT @pinot: someeetimesas you'rre lucky if almi...
# 2           2  Angkatan CCS / wiro paham nih... https://t.co/...
# 3           3  Toksik bener bocah busetttttt https://t.co/b5n...
# 4           4  Akun2 provokator yang lagi manasin mesin 2024 ...
# 5           5                          @acotenri @EnzyStoria MAU
# 6           6  🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡 https://t...
# 7           7  Sedih beneran disangka nyindir. Elu aje yg sen...
# 8           8  Walau gw fans Spurs, gw harus akui, trisula li...
# 9           9  Desember ini kita ketawa-ketawa di Bali yuk! ❤...
#
#                                               step01
# 0  vanlith_gl pesanku untuk pengusaha sablon jela...
# 1  pinot someeetimesas yourre lucky if almigjhty ...
# 2           angkatan ccs wiro paham nih coakwyauysuo
# 3          toksik bener bocah busetttttt cobnjnjtgqb
# 4  akun provokator yang lagi manasin mesin   ini ...
# 5                            acotenri enzystoria mau
# 6                                        coupfokbeoa
# 7  sedih beneran disangka nyindir elu aje yg sens...
# 8  walau gw fans spurs gw harus akui trisula lini...
# 9  desember ini kita ketawa ketawa di bali yuk co...

# %% [markdown]
# ## Hapus Data Kosong

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  198 non-null    int64
#  1   Tweets      198 non-null    object
#  2   step01      198 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 6 to 179
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7 non-null      int64
#  1   Tweets      7 non-null      object
#  2   step01      7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df_hapus.head(10)
# Out:
#      Unnamed: 0                                             Tweets  \
# 6             6  🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡🫡 https://t...
# 38           38           ❤️❤️❤️❤️❤️❤️❤️❤️ https://t.co/VUX9aXWWwt
# 51           51                  😭😭😭😭😭😭😭😭😭 https://t.co/Cw58pksyhd
# 101         101                😭😭😭😭😭😭😭😭😭😭😭 https://t.co/ifE2yzRfkK
# 134         134                    👏👏👏👏👏👏👏 https://t.co/L74viUSlur
# 148         148                    👏👏👏👏👏👏👏 https://t.co/q6riKAriXN
# 179         179                     🔥🔥🔥🔥🔥🔥 https://t.co/0vni4DljRE
#
#           step01
# 6    coupfokbeoa
# 38          covu
# 51    cocwpksyhd
# 101  coifeyzrfkk
# 134   colviuslur
# 148    coqrikari
# 179   covnidljre

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191 entries, 0 to 197
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  191 non-null    float64
#  1   Tweets      191 non-null    object
#  2   step01      191 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 6.0+ KB

# %%
df_new
# Out:
#      Unnamed: 0                                             Tweets  \
# 0           0.0  RT @vanlith_gl: Pesanku untuk pengusaha sablon...
# 1           1.0  RT @pinot: someeetimesas you'rre lucky if almi...
# 2           2.0  Angkatan CCS / wiro paham nih... https://t.co/...
# 3           3.0  Toksik bener bocah busetttttt https://t.co/b5n...
# 4           4.0  Akun2 provokator yang lagi manasin mesin 2024 ...
# ..          ...                                                ...
# 193       193.0  Ajegile udah 0-3 aja Arsenal. Udah ah nontonny...
# 194       194.0                           Maap salah, Partey ada 🙏
# 195       195.0  Eh iya maap. Partey ada ya. Tetep aja tanpa Od...
# 196       196.0  Penampilan brilian sang headliner @bene_dion d...
# 197       197.0  Arsenal mainnya bagus banget ya. Gokil Arteta ...
#
#                                                 step01
# 0    vanlith_gl pesanku untuk pengusaha sablon jela...
# 1    pinot someeetimesas yourre lucky if almigjhty ...
# 2             angkatan ccs wiro paham nih coakwyauysuo
# 3            toksik bener bocah busetttttt cobnjnjtgqb
# 4    akun provokator yang lagi manasin mesin   ini ...
# ..                                                 ...
# 193  ajegile udah     aja arsenal udah ah nontonnya...
# 194                              maap salah partey ada
# 195  eh iya maap partey ada ya tetep aja tanpa odeg...
# 196  penampilan brilian sang headliner bene_dion di...
# 197   arsenal mainnya bagus banget ya gokil arteta ini
#
# [191 rows x 3 columns]

# %% [markdown]
# ## Normalisasi kata slang menjadi baku

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Adam\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df["step01"].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#     Unnamed: 0                                             Tweets  \
# 0          0.0  RT @vanlith_gl: Pesanku untuk pengusaha sablon...
# 1          1.0  RT @pinot: someeetimesas you'rre lucky if almi...
# 2          2.0  Angkatan CCS / wiro paham nih... https://t.co/...
# 3          3.0  Toksik bener bocah busetttttt https://t.co/b5n...
# 4          4.0  Akun2 provokator yang lagi manasin mesin 2024 ...
# 5          5.0                          @acotenri @EnzyStoria MAU
# 7          7.0  Sedih beneran disangka nyindir. Elu aje yg sen...
# 8          8.0  Walau gw fans Spurs, gw harus akui, trisula li...
# 9          9.0  Desember ini kita ketawa-ketawa di Bali yuk! ❤...
# 10        10.0               RT @aimi_asi: Mantap Kak @nggirma ❤️
#
#                                                step01  \
# 0   vanlith_gl pesanku untuk pengusaha sablon jela...
# 1   pinot someeetimesas yourre lucky if almigjhty ...
# 2            angkatan ccs wiro paham nih coakwyauysuo
# 3           toksik bener bocah busetttttt cobnjnjtgqb
# 4   akun provokator yang lagi manasin mesin   ini ...
# 5                             acotenri enzystoria mau
# 7   sedih beneran disangka nyindir elu aje yg sens...
# 8   walau gw fans spurs gw harus akui trisula lini...
# 9   desember ini kita ketawa ketawa di bali yuk co...
# 10                        aimi_asi mantap kak nggirma
#
#                                                tokens
# 0   [vanlith_gl, pesanku, untuk, pengusaha, sablon...
# 1   [pinot, someeetimesas, yourre, lucky, if, almi...
# 2     [angkatan, ccs, wiro, paham, nih, coakwyauysuo]
# 3     [toksik, bener, bocah, busetttttt, cobnjnjtgqb]
# 4   [akun, provokator, yang, lagi, manasin, mesin,...
# 5                         [acotenri, enzystoria, mau]
# 7   [sedih, beneran, disangka, nyindir, elu, aje, ...
# 8   [walau, gw, fans, spurs, gw, harus, akui, tris...
# 9   [desember, ini, kita, ketawa, ketawa, di, bali...
# 10                   [aimi_asi, mantap, kak, nggirma]

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#     Unnamed: 0                                             Tweets  \
# 0          0.0  RT @vanlith_gl: Pesanku untuk pengusaha sablon...
# 1          1.0  RT @pinot: someeetimesas you'rre lucky if almi...
# 2          2.0  Angkatan CCS / wiro paham nih... https://t.co/...
# 3          3.0  Toksik bener bocah busetttttt https://t.co/b5n...
# 4          4.0  Akun2 provokator yang lagi manasin mesin 2024 ...
# 5          5.0                          @acotenri @EnzyStoria MAU
# 7          7.0  Sedih beneran disangka nyindir. Elu aje yg sen...
# 8          8.0  Walau gw fans Spurs, gw harus akui, trisula li...
# 9          9.0  Desember ini kita ketawa-ketawa di Bali yuk! ❤...
# 10        10.0               RT @aimi_asi: Mantap Kak @nggirma ❤️
#
#                                                step01  \
# 0   vanlith_gl pesanku untuk pengusaha sablon jela...
# 1   pinot someeetimesas yourre lucky if almigjhty ...
# 2            angkatan ccs wiro paham nih coakwyauysuo
# 3           toksik bener bocah busetttttt cobnjnjtgqb
# 4   akun provokator yang lagi manasin mesin   ini ...
# 5                             acotenri enzystoria mau
# 7   sedih beneran disangka nyindir elu aje yg sens...
# 8   walau gw fans spurs gw harus akui trisula lini...
# 9   desember ini kita ketawa ketawa di bali yuk co...
# 10                        aimi_asi mantap kak nggirma
#
#                                                tokens  \
# 0   [vanlith_gl, pesanku, untuk, pengusaha, sablon...
# 1   [pinot, someeetimesas, yourre, lucky, if, almi...
# 2     [angkatan, ccs, wiro, paham, nih, coakwyauysuo]
# 3     [toksik, bener, bocah, busetttttt, cobnjnjtgqb]
# 4   [akun, provokator, yang, lagi, manasin, mesin,...
# 5                         [acotenri, enzystoria, mau]
# 7   [sedih, beneran, disangka, nyindir, elu, aje, ...
# 8   [walau, gw, fans, spurs, gw, harus, akui, tris...
# 9   [desember, ini, kita, ketawa, ketawa, di, bali...
# 10                   [aimi_asi, mantap, kak, nggirma]
#
#                                          final_tokens  \
# 0   [vanlith_gl, pesanku, untuk, pengusaha, sablon...
# 1   [pinot, someeetimesas, yourre, lucky, if, almi...
# 2     [angkatan, ccs, wiro, paham, nih, coakwyauysuo]
# 3     [toksik, bener, bocah, busetttttt, cobnjnjtgqb]
# 4   [akun, provokator, yang, lagi, manasin, mesin,...
# 5                         [acotenri, enzystoria, mau]
# 7   [sedih, beneran, disangka, nyindir, elu, aje, ...
# 8   [walau, gw, fans, spurs, gw, harus, akui, tris...
# 9   [desember, ini, kita, ketawa, ketawa, di, bali...
# 10                   [aimi_asi, mantap, kak, nggirma]
#
#                                                step02
# 0   vanlith_gl pesanku untuk pengusaha sablon jela...
# 1   pinot someeetimesas yourre lucky if almigjhty ...
# 2            angkatan ccs wiro paham nih coakwyauysuo
# 3           toksik bener bocah busetttttt cobnjnjtgqb
# 4   akun provokator yang lagi manasin mesin ini ga...
# 5                             acotenri enzystoria mau
# 7   sedih beneran disangka nyindir elu aje yg sens...
# 8   walau gw fans spurs gw harus akui trisula lini...
# 9   desember ini kita ketawa ketawa di bali yuk co...
# 10                        aimi_asi mantap kak nggirma

# %% [markdown]
# ## Simpan clean dataset

# %%
df_new.to_csv('clean_dataset.csv',sep=";")

# %%
# Stemming menggunakan Sastrawi

# %%
import pandas as pd

# %%
dataset = pd.read_csv('clean_dataset.csv', sep=';')

# %%
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0         0.0
# 1             1         1.0
# 2             2         2.0
# 3             3         3.0
# 4             4         4.0
#
#                                               Tweets  \
# 0  RT @vanlith_gl: Pesanku untuk pengusaha sablon...
# 1  RT @pinot: someeetimesas you'rre lucky if almi...
# 2  Angkatan CCS / wiro paham nih... https://t.co/...
# 3  Toksik bener bocah busetttttt https://t.co/b5n...
# 4  Akun2 provokator yang lagi manasin mesin 2024 ...
#
#                                               step01  \
# 0  vanlith_gl pesanku untuk pengusaha sablon jela...
# 1  pinot someeetimesas yourre lucky if almigjhty ...
# 2           angkatan ccs wiro paham nih coakwyauysuo
# 3          toksik bener bocah busetttttt cobnjnjtgqb
# 4  akun provokator yang lagi manasin mesin   ini ...
#
#                                               tokens  \
# 0  ['vanlith_gl', 'pesanku', 'untuk', 'pengusaha'...
# 1  ['pinot', 'someeetimesas', 'yourre', 'lucky', ...
# 2  ['angkatan', 'ccs', 'wiro', 'paham', 'nih', 'c...
# 3  ['toksik', 'bener', 'bocah', 'busetttttt', 'co...
# 4  ['akun', 'provokator', 'yang', 'lagi', 'manasi...
#
#                                         final_tokens  \
# 0  ['vanlith_gl', 'pesanku', 'untuk', 'pengusaha'...
# 1  ['pinot', 'someeetimesas', 'yourre', 'lucky', ...
# 2  ['angkatan', 'ccs', 'wiro', 'paham', 'nih', 'c...
# 3  ['toksik', 'bener', 'bocah', 'busetttttt', 'co...
# 4  ['akun', 'provokator', 'yang', 'lagi', 'manasi...
#
#                                               step02
# 0  vanlith_gl pesanku untuk pengusaha sablon jela...
# 1  pinot someeetimesas yourre lucky if almigjhty ...
# 2           angkatan ccs wiro paham nih coakwyauysuo
# 3          toksik bener bocah busetttttt cobnjnjtgqb
# 4  akun provokator yang lagi manasin mesin ini ga...

# %%
# !pip install sastrawi
# Out:
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
 
factory = StopWordRemoverFactory()

more_stopword = ['sih', 'nya','rt','loh','lah', 'dd', 'mah', 'nye', 'eh', 'ehh', 'ah', 'yang','yg']
 
# Tambahkan Stopword Baru
data = factory.get_stop_words()+more_stopword

stopwords_sastrawi = factory.create_stop_word_remover()

dictionary = ArrayDictionary(data)
str_stopwords = StopWordRemover(dictionary)

# %%
dataset['finalText_str'] = dataset['step02'].apply(str)

# %%
i=0
final_string = []
s = ""
for sentence in dataset["finalText_str"].values:
    filteredSentence = []
    EachReviewText = ""
    st = str_stopwords.remove(sentence)
    s = (stemmer.stem(st))
    filteredSentence.append(s)
    
    EachReviewText = ' '.join(filteredSentence)
    final_string.append(EachReviewText)

# %%
dataset.loc[:, ('ProcessedText')] = final_string

# %%
dataset
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0         0.0
# 1               1         1.0
# 2               2         2.0
# 3               3         3.0
# 4               4         4.0
# ..            ...         ...
# 186           193       193.0
# 187           194       194.0
# 188           195       195.0
# 189           196       196.0
# 190           197       197.0
#
#                                                 Tweets  \
# 0    RT @vanlith_gl: Pesanku untuk pengusaha sablon...
# 1    RT @pinot: someeetimesas you'rre lucky if almi...
# 2    Angkatan CCS / wiro paham nih... https://t.co/...
# 3    Toksik bener bocah busetttttt https://t.co/b5n...
# 4    Akun2 provokator yang lagi manasin mesin 2024 ...
# ..                                                 ...
# 186  Ajegile udah 0-3 aja Arsenal. Udah ah nontonny...
# 187                           Maap salah, Partey ada 🙏
# 188  Eh iya maap. Partey ada ya. Tetep aja tanpa Od...
# 189  Penampilan brilian sang headliner @bene_dion d...
# 190  Arsenal mainnya bagus banget ya. Gokil Arteta ...
#
#                                                 step01  \
# 0    vanlith_gl pesanku untuk pengusaha sablon jela...
# 1    pinot someeetimesas yourre lucky if almigjhty ...
# 2             angkatan ccs wiro paham nih coakwyauysuo
# 3            toksik bener bocah busetttttt cobnjnjtgqb
# 4    akun provokator yang lagi manasin mesin   ini ...
# ..                                                 ...
# 186  ajegile udah     aja arsenal udah ah nontonnya...
# 187                              maap salah partey ada
# 188  eh iya maap partey ada ya tetep aja tanpa odeg...
# 189  penampilan brilian sang headliner bene_dion di...
# 190   arsenal mainnya bagus banget ya gokil arteta ini
#
#                                                 tokens  \
# 0    ['vanlith_gl', 'pesanku', 'untuk', 'pengusaha'...
# 1    ['pinot', 'someeetimesas', 'yourre', 'lucky', ...
# 2    ['angkatan', 'ccs', 'wiro', 'paham', 'nih', 'c...
# 3    ['toksik', 'bener', 'bocah', 'busetttttt', 'co...
# 4    ['akun', 'provokator', 'yang', 'lagi', 'manasi...
# ..                                                 ...
# 186  ['ajegile', 'udah', 'aja', 'arsenal', 'udah', ...
# 187                 ['maap', 'salah', 'partey', 'ada']
# 188  ['eh', 'iya', 'maap', 'partey', 'ada', 'ya', '...
# 189  ['penampilan', 'brilian', 'sang', 'headliner',...
# 190  ['arsenal', 'mainnya', 'bagus', 'banget', 'ya'...
#
#                                           final_tokens  \
# 0    ['vanlith_gl', 'pesanku', 'untuk', 'pengusaha'...
# 1    ['pinot', 'someeetimesas', 'yourre', 'lucky', ...
# 2    ['angkatan', 'ccs', 'wiro', 'paham', 'nih', 'c...
# 3    ['toksik', 'bener', 'bocah', 'busetttttt', 'co...
# 4    ['akun', 'provokator', 'yang', 'lagi', 'manasi...
# ..                                                 ...
# 186  ['ajegile', 'udah', 'aja', 'arsenal', 'udah', ...
# 187                 ['maap', 'salah', 'partey', 'ada']
# 188  ['eh', 'iya', 'maap', 'partey', 'ada', 'ya', '...
# 189  ['penampilan', 'brilian', 'sang', 'headliner',...
# 190  ['arsenal', 'mainnya', 'bagus', 'banget', 'ya'...
#
#                                                 step02  \
# 0    vanlith_gl pesanku untuk pengusaha sablon jela...
# 1    pinot someeetimesas yourre lucky if almigjhty ...
# 2             angkatan ccs wiro paham nih coakwyauysuo
# 3            toksik bener bocah busetttttt cobnjnjtgqb
# 4    akun provokator yang lagi manasin mesin ini ga...
# ..                                                 ...
# 186  ajegile udah aja arsenal udah ah nontonnya sam...
# 187                              maap salah partey ada
# 188  eh iya maap partey ada ya tetep aja tanpa odeg...
# 189  penampilan brilian sang headliner bene_dion di...
# 190   arsenal mainnya bagus banget ya gokil arteta ini
#
#                                          finalText_str  \
# 0    vanlith_gl pesanku untuk pengusaha sablon jela...
# 1    pinot someeetimesas yourre lucky if almigjhty ...
# 2             angkatan ccs wiro paham nih coakwyauysuo
# 3            toksik bener bocah busetttttt cobnjnjtgqb
# 4    akun provokator yang lagi manasin mesin ini ga...
# ..                                                 ...
# 186  ajegile udah aja arsenal udah ah nontonnya sam...
# 187                              maap salah partey ada
# 188  eh iya maap partey ada ya tetep aja tanpa odeg...
# 189  penampilan brilian sang headliner bene_dion di...
# 190   arsenal mainnya bagus banget ya gokil arteta ini
#
#                                          ProcessedText
# 0    vanlith gl pesan usaha sablon jelang pokok jan...
# 1    pot someeetimesas yourre lucky if almigjhty de...
# 2               angkat ccs wiro paham nih coakwyauysuo
# 3            toksik bener bocah busetttttt cobnjnjtgqb
# 4    akun provokator lagi manasin mesin ga perlu di...
# ..                                                 ...
# 186  ajegile udah aja arsenal udah nontonnya sampe ...
# 187                                  maap salah partey
# 188  iya maap partey ya tetep aja odegaard sang kap...
# 189  tampil brilian sang headliner bene dion malam ...
# 190             arsenal main bagus banget gokil arteta
#
# [191 rows x 9 columns]

# %%
dataset.to_csv('clean_dataset_stem.csv',sep=';')
